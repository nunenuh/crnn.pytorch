# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.random.random((2,2))

# %%
# Out:
# array([[0.36222482, 0.82854878],
#        [0.87156382, 0.7347049 ]])

# %%
alist = [
    [1,0,1],
    [0,1,0],
    [1,0,1]
]
mat1 = np.array(alist)

# %%
plt.imshow(mat1, cmap='gray')

# %%
R,G,B = [255,0,0],[0,255,0],[0,0,255]

alist_new = [
    [R,G,R],
    [R,G,B],
    [G,G,R],
    [G,G,R],
    
]

mat2 = np.array(alist_new).astype(np.uint8)
mat2.shape
# Out:
# (4, 3, 3)

# %%
plt.imshow(mat2, cmap='gray')

# %%
import cv2 as cv

# %%
img = cv.imread('/data/test.jpeg')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
# img_resize = cv.resize(img, (188,128))

# %%
img_copy = img.copy()[:, :, 0]

img_ops = img_copy <200
plt.imshow(img_ops, cmap='gray')
